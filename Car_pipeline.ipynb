# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd
import pandas_gbq as gbq
from sklearn.preprocessing import Normalizer,StandardScaler,OneHotEncoder
from sklearn.pipeline import Pipeline   
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import chi2
import numpy as np

# %%
from pandas import DataFrame

# %%
cred=service_account.Credentials.from_service_account_file(
    "service_key.json"
)
client = bigquery.Client(credentials=cred, project=cred.project_id,)
sql="""
select *
from `silver-rain-325220.cars.carsone`
    """
df=client.query(sql).to_dataframe()

# %%
cat=list(df.select_dtypes(include='object').columns)
df.loc[:,cat]
# Out:
#         make fuel_type num_of_doors body_style drive_wheels engine_location  \
# 0     peugot       gas         four      sedan          rwd           front
# 1     peugot       gas         four      sedan          rwd           front
# 2     peugot       gas         four      sedan          rwd           front
# 3     peugot       gas         four      wagon          rwd           front
# 4     peugot       gas         four      wagon          rwd           front
# ..       ...       ...          ...        ...          ...             ...
# 198  porsche       gas          two  hatchback          rwd           front
# 199    mazda       gas          two  hatchback          rwd           front
# 200    mazda       gas          two  hatchback          rwd           front
# 201    mazda       gas          two  hatchback          rwd           front
# 202    mazda       gas          two  hatchback          rwd           front
#
#     engine_type num_of_cylinders fuel_system
# ...

# %%
def frame_summ(dataframe)->DataFrame:
    summary=[]
    for i in dataframe.columns:
        summary.append(len(dataframe[i].unique()))
    data=pd.DataFrame({'unique_val':summary},index=dataframe.columns)
    data['d_types']=dataframe.dtypes
    return data

# %%
df.shape

# dave=pd.DataFrame({'unique_val':summary},index=df.columns)
# Out:
# (203, 20)

# %%
nana.head()
# Out:
#               unique_val d_types
# make                  21  object
# fuel_type              2  object
# num_of_doors           2  object
# body_style             5  object
# drive_wheels           3  object

# %%
df = gbq.read_gbq(sql, project_id=cred.project_id, credentials=cred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\dcone\Desktop\Data Engineering\Car_pipeline.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dcone/Desktop/Data%20Engineering/Car_pipeline.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df = gbq.read_gbq(sql, project_id=cred.project_id, credentials=cred)
#
# File c:\Users\dcone\Desktop\Nyame\lib\site-packages\pandas_gbq\gbq.py:884, in read_gbq(query_or_table, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, max_results, verbose, private_key, progress_bar_type, dtypes)
#     881 if dialect is None:
#     882     dialect = "standard"
# --> 884 _test_google_api_imports()
#     886 if verbose is not None and FEATURES.pandas_has_deprecated_verbose:
#     887     warnings.warn(
# ...
